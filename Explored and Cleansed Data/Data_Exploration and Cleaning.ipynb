# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
tree_census = pd.read_csv('Tree_Data.csv')

# %%
tree_census
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
#        health                           spc_latin           spc_common  \
# 0        Fair                         Acer rubrum            red maple
# 1        Fair                   Quercus palustris              pin oak
# 2        Good  Gleditsia triacanthos var. inermis          honeylocust
# 3        Good  Gleditsia triacanthos var. inermis          honeylocust
# 4        Good                     Tilia americana      American linden
# ...       ...                                 ...                  ...
# 683783   Good                   Quercus palustris              pin oak
# 683784   Good                 Cladrastis kentukea  Kentucky yellowwood
# 683785   Good                         Acer rubrum            red maple
# 683786   Good                         Acer rubrum            red maple
# 683787   Fair                         Acer rubrum            red maple
#
#        steward guards  sidewalk         user_type problems root_stone  \
# 0         None   None  NoDamage  TreesCount Staff     None         No
# 1         None   None    Damage  TreesCount Staff   Stones        Yes
# 2         1or2   None    Damage         Volunteer     None         No
# 3         None   None    Damage         Volunteer   Stones        Yes
# 4         None   None    Damage         Volunteer   Stones        Yes
# ...        ...    ...       ...               ...      ...        ...
# 683783    None   None    Damage         Volunteer     None         No
# 683784    1or2   None  NoDamage         Volunteer     None         No
# 683785    None   None    Damage         Volunteer     None         No
# 683786    None   None  NoDamage  TreesCount Staff     None         No
# 683787    None   None  NoDamage  TreesCount Staff     None         No
#
#        root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# 0              No         No         No         No         No         No
# 1              No         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3              No         No         No         No         No         No
# 4              No         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_shoe brch_other                  address  postcode       zip_city  \
# 0             No         No        108-005 70 AVENUE     11375   Forest Hills
# 1             No         No         147-074 7 AVENUE     11357     Whitestone
# 2             No         No        390 MORGAN AVENUE     11211       Brooklyn
# 3             No         No        1027 GRAND STREET     11211       Brooklyn
# 4             No         No             603 6 STREET     11215       Brooklyn
# ...          ...        ...                      ...       ...            ...
# 683783        No         No          32 MARCY AVENUE     11211       Brooklyn
# 683784        No         No  67-035 SELFRIDGE STREET     11375   Forest Hills
# 683785        No         No       130 BIDWELL AVENUE     10314  Staten Island
# 683786        No         No      1985 ANTHONY AVENUE     10457          Bronx
# 683787        No         No        69-069 183 STREET     11365  Fresh Meadows
#
#         community board  borocode        borough  cncldist  st_assem  \
# 0                   406         4         Queens        29        28
# 1                   407         4         Queens        19        27
# 2                   301         3       Brooklyn        34        50
# 3                   301         3       Brooklyn        34        53
# 4                   306         3       Brooklyn        39        44
# ...                 ...       ...            ...       ...       ...
# 683783              301         3       Brooklyn        34        53
# 683784              406         4         Queens        29        28
# 683785              501         5  Staten Island        50        63
# 683786              205         2          Bronx        15        86
# 683787              408         4         Queens        24        25
#
#         st_senate   nta               nta_name  boro_ct     state   latitude  \
# 0              16  QN17           Forest Hills  4073900  New York  40.723092
# 1              11  QN49             Whitestone  4097300  New York  40.794111
# 2              18  BK90      East Williamsburg  3044900  New York  40.717581
# 3              18  BK90      East Williamsburg  3044900  New York  40.713537
# 4              21  BK37     Park Slope-Gowanus  3016500  New York  40.666778
# ...           ...   ...                    ...      ...       ...        ...
# 683783         18  BK73  North Side-South Side  3051900  New York  40.713211
# 683784         15  QN17           Forest Hills  4070700  New York  40.715194
# 683785         24  SI07            Westerleigh  5020100  New York  40.620762
# 683786         33  BX41             Mount Hope  2023502  New York  40.850828
# 683787         11  QN41   Fresh Meadows-Utopia  4134100  New York  40.732165
#
#         longitude          x_sp         y_sp  council district  census tract  \
# 0      -73.844215  1.027431e+06  202756.7687              29.0         739.0
# 1      -73.818679  1.034456e+06  228644.8374              19.0         973.0
# 2      -73.936608  1.001823e+06  200716.8913              34.0         449.0
# 3      -73.934456  1.002420e+06  199244.2531              34.0         449.0
# 4      -73.975979  9.909138e+05  182202.4260              39.0         165.0
# ...           ...           ...          ...               ...           ...
# 683783 -73.954944  9.967407e+05  199121.6363              34.0         519.0
# 683784 -73.856650  1.023989e+06  199873.6475              29.0         707.0
# 683785 -74.136517  9.463514e+05  165466.0763              50.0         201.0
# 683786 -73.903115  1.011054e+06  249271.9507              15.0       23502.0
# 683787 -73.787526  1.043136e+06  206095.5383              24.0        1341.0
#
#               bin           bbl
# 0       4052307.0  4.022210e+09
# 1       4101931.0  4.044750e+09
# 2       3338310.0  3.028870e+09
# 3       3338342.0  3.029250e+09
# 4       3025654.0  3.010850e+09
# ...           ...           ...
# 683783  3062513.0  3.023690e+09
# 683784  4075448.0  4.031810e+09
# 683785  5011657.0  5.004080e+09
# 683786  2007757.0  2.028120e+09
# 683787  4153657.0  4.071360e+09
#
# [683788 rows x 45 columns]

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subset = tree_census[['tree_id', 'block_id','tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin','steward',
        'sidewalk', 'user_type', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_census_subset
# Out:
#         tree_id  block_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683    348711         3           0   OnCurb  Alive   Fair
# 1        200540    315986        21           0   OnCurb  Alive   Fair
# 2        204026    218365         3           0   OnCurb  Alive   Good
# 3        204337    217969        10           0   OnCurb  Alive   Good
# 4        189565    223043        21           0   OnCurb  Alive   Good
# ...         ...       ...       ...         ...      ...    ...    ...
# 683783   155433    217978        25           0   OnCurb  Alive   Good
# 683784   183795    348185         7           0   OnCurb  Alive   Good
# 683785   166161    401670        12           0   OnCurb  Alive   Good
# 683786   184028    504204         9           0   OnCurb  Alive   Good
# 683787   200607    306527        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk  \
# 0                              Acer rubrum    None  NoDamage
# 1                        Quercus palustris    None    Damage
# 2       Gleditsia triacanthos var. inermis    1or2    Damage
# 3       Gleditsia triacanthos var. inermis    None    Damage
# 4                          Tilia americana    None    Damage
# ...                                    ...     ...       ...
# 683783                   Quercus palustris    None    Damage
# 683784                 Cladrastis kentukea    1or2  NoDamage
# 683785                         Acer rubrum    None    Damage
# 683786                         Acer rubrum    None  NoDamage
# 683787                         Acer rubrum    None  NoDamage
#
#                user_type problems root_stone root_grate root_other trunk_wire  \
# 0       TreesCount Staff     None         No         No         No         No
# 1       TreesCount Staff   Stones        Yes         No         No         No
# 2              Volunteer     None         No         No         No         No
# 3              Volunteer   Stones        Yes         No         No         No
# 4              Volunteer   Stones        Yes         No         No         No
# ...                  ...      ...        ...        ...        ...        ...
# 683783         Volunteer     None         No         No         No         No
# 683784         Volunteer     None         No         No         No         No
# 683785         Volunteer     None         No         No         No         No
# 683786  TreesCount Staff     None         No         No         No         No
# 683787  TreesCount Staff     None         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 0              No         No         No        No         No
# 1              No         No         No        No         No
# 2              No         No         No        No         No
# 3              No         No         No        No         No
# 4              No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 683783         No         No         No        No         No
# 683784         No         No         No        No         No
# 683785         No         No         No        No         No
# 683786         No         No         No        No         No
# 683787         No         No         No        No         No
#
# [683788 rows x 21 columns]

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id           0
# block_id          0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# sidewalk      31616
# user_type         0
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#         tree_id  block_id  tree_dbh  stump_diam        curb_loc status health  \
# 37       211205    302080         0          16          OnCurb  Stump    NaN
# 57       187807    506266         0           0          OnCurb   Dead    NaN
# 196      208322    222858        10           0          OnCurb   Dead    NaN
# 209      209058    415850         6           0          OnCurb   Dead    NaN
# 239      203597    301947         0          15          OnCurb  Stump    NaN
# ...         ...       ...       ...         ...             ...    ...    ...
# 683693   156162    108193         3           0  OffsetFromCurb   Dead    NaN
# 683695   170888    231931         0           5          OnCurb  Stump    NaN
# 683697   177922    410634         0          17          OnCurb  Stump    NaN
# 683698   193791    208850         3           0          OnCurb   Dead    NaN
# 683699   172660    349995         0           4          OnCurb  Stump    NaN
#
#        spc_latin steward sidewalk         user_type problems root_stone  \
# 37           NaN     NaN      NaN  TreesCount Staff      NaN         No
# 57           NaN     NaN      NaN         Volunteer      NaN         No
# 196          NaN     NaN      NaN         Volunteer      NaN         No
# 209          NaN     NaN      NaN  TreesCount Staff      NaN         No
# 239          NaN     NaN      NaN         Volunteer      NaN         No
# ...          ...     ...      ...               ...      ...        ...
# 683693       NaN     NaN      NaN         Volunteer      NaN         No
# 683695       NaN     NaN      NaN  TreesCount Staff      NaN         No
# 683697       NaN     NaN      NaN         Volunteer      NaN         No
# 683698       NaN     NaN      NaN  TreesCount Staff      NaN         No
# 683699       NaN     NaN      NaN  TreesCount Staff      NaN         No
#
#        root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# 37             No         No         No         No         No         No
# 57             No         No         No         No         No         No
# 196            No         No         No         No         No         No
# 209            No         No         No         No         No         No
# 239            No         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683693         No         No         No         No         No         No
# 683695         No         No         No         No         No         No
# 683697         No         No         No         No         No         No
# 683698         No         No         No         No         No         No
# 683699         No         No         No         No         No         No
#
#        brch_shoe brch_other
# 37            No         No
# 57            No         No
# 196           No         No
# 209           No         No
# 239           No         No
# ...          ...        ...
# 683693        No         No
# 683695        No         No
# 683697        No         No
# 683698        No         No
# 683699        No         No
#
# [31616 rows x 21 columns]

# %%
tree_census_subset[tree_census_subset['spc_latin'].isna()]
# Out:
#         tree_id  block_id  tree_dbh  stump_diam        curb_loc status health  \
# 37       211205    302080         0          16          OnCurb  Stump    NaN
# 57       187807    506266         0           0          OnCurb   Dead    NaN
# 196      208322    222858        10           0          OnCurb   Dead    NaN
# 209      209058    415850         6           0          OnCurb   Dead    NaN
# 239      203597    301947         0          15          OnCurb  Stump    NaN
# ...         ...       ...       ...         ...             ...    ...    ...
# 683693   156162    108193         3           0  OffsetFromCurb   Dead    NaN
# 683695   170888    231931         0           5          OnCurb  Stump    NaN
# 683697   177922    410634         0          17          OnCurb  Stump    NaN
# 683698   193791    208850         3           0          OnCurb   Dead    NaN
# 683699   172660    349995         0           4          OnCurb  Stump    NaN
#
#        spc_latin steward sidewalk         user_type problems root_stone  \
# 37           NaN     NaN      NaN  TreesCount Staff      NaN         No
# 57           NaN     NaN      NaN         Volunteer      NaN         No
# 196          NaN     NaN      NaN         Volunteer      NaN         No
# 209          NaN     NaN      NaN  TreesCount Staff      NaN         No
# 239          NaN     NaN      NaN         Volunteer      NaN         No
# ...          ...     ...      ...               ...      ...        ...
# 683693       NaN     NaN      NaN         Volunteer      NaN         No
# 683695       NaN     NaN      NaN  TreesCount Staff      NaN         No
# 683697       NaN     NaN      NaN         Volunteer      NaN         No
# 683698       NaN     NaN      NaN  TreesCount Staff      NaN         No
# 683699       NaN     NaN      NaN  TreesCount Staff      NaN         No
#
#        root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# 37             No         No         No         No         No         No
# 57             No         No         No         No         No         No
# 196            No         No         No         No         No         No
# 209            No         No         No         No         No         No
# 239            No         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683693         No         No         No         No         No         No
# 683695         No         No         No         No         No         No
# 683697         No         No         No         No         No         No
# 683698         No         No         No         No         No         No
# 683699         No         No         No         No         No         No
#
#        brch_shoe brch_other
# 37            No         No
# 57            No         No
# 196           No         No
# 209           No         No
# 239           No         No
# ...          ...        ...
# 683693        No         No
# 683695        No         No
# 683697        No         No
# 683698        No         No
# 683699        No         No
#
# [31619 rows x 21 columns]

# %%
tree_census_subset.describe()
# Out:
#              tree_id       block_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000  683788.000000
# mean   365205.011085  313793.096236      11.279787       0.432463
# std    208122.092902  114839.024312       8.723042       3.290241
# min         3.000000  100002.000000       0.000000       0.000000
# 25%    186582.750000  221556.000000       4.000000       0.000000
# 50%    366214.500000  319967.000000       9.000000       0.000000
# 75%    546170.250000  404624.000000      16.000000       0.000000
# max    722694.000000  999999.000000     450.000000     140.000000

# %%
tree_census_subset.dtypes
# Out:
# tree_id        int64
# block_id       int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# user_type     object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
tree_census_subset.hist(bins=60,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'block_id'}>],
#        [<AxesSubplot:title={'center':'tree_dbh'}>,
#         <AxesSubplot:title={'center':'stump_diam'}>]], dtype=object)

# %%
big_trees = tree_census_subset[tree_census_subset['tree_dbh']>50]
big_trees
# Out:
#         tree_id  block_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583    226040       425           0          OnCurb  Alive   Good
# 3738     199546    315695        51           0          OnCurb  Alive   Good
# 4887     139665    409474        72           0  OffsetFromCurb  Alive   Good
# 6724     209349    415127       122           0          OnCurb  Alive   Good
# 10083    215075    515054       169           0          OnCurb  Alive   Good
# ...         ...       ...       ...         ...             ...    ...    ...
# 675265   179496    322014        52           0  OffsetFromCurb  Alive   Good
# 677954   166796    348127        54           0          OnCurb  Alive   Good
# 679894   169501    312374        51           0          OnCurb  Alive   Good
# 681736   179366    349326       281           0          OnCurb  Alive   Fair
# 682788   183910    505123       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin steward  sidewalk  \
# 2405                       Quercus bicolor    1or2    Damage
# 3738                      Acer saccharinum    None  NoDamage
# 4887                      Acer saccharinum    None  NoDamage
# 6724                     Quercus palustris    None    Damage
# 10083   Gleditsia triacanthos var. inermis    None  NoDamage
# ...                                    ...     ...       ...
# 675265                   Quercus palustris    None    Damage
# 677954                    Acer saccharinum    None  NoDamage
# 679894                        Quercus alba    None  NoDamage
# 681736                   Quercus palustris    None    Damage
# 682788                                 NaN     NaN       NaN
#
#                user_type      problems root_stone root_grate root_other  \
# 2405     NYC Parks Staff          None         No         No         No
# 3738    TreesCount Staff        Stones        Yes         No         No
# 4887    TreesCount Staff          None         No         No         No
# 6724    TreesCount Staff          None         No         No         No
# 10083   TreesCount Staff          None         No         No         No
# ...                  ...           ...        ...        ...        ...
# 675265         Volunteer        Stones        Yes         No         No
# 677954         Volunteer        Stones        Yes         No         No
# 679894         Volunteer  BranchLights         No         No         No
# 681736  TreesCount Staff          None         No         No         No
# 682788         Volunteer           NaN         No         No         No
#
#        trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other
# 2405           No         No         No         No        No         No
# 3738           No         No         No         No        No         No
# 4887           No         No         No         No        No         No
# 6724           No         No         No         No        No         No
# 10083          No         No         No         No        No         No
# ...           ...        ...        ...        ...       ...        ...
# 675265         No         No         No         No        No         No
# 677954         No         No         No         No        No         No
# 679894         No         No         No        Yes        No         No
# 681736         No         No         No         No        No         No
# 682788         No         No         No         No        No         No
#
# [364 rows x 21 columns]

# %%
big_trees[['tree_id','tree_dbh']].plot(kind='scatter',x='tree_id',y='tree_dbh',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='tree_dbh'>

# %%
pd.DataFrame(tree_census_subset['spc_latin'].value_counts())
# Out:
#                                     spc_latin
# Platanus x acerifolia                   87014
# Gleditsia triacanthos var. inermis      64264
# Pyrus calleryana                        58931
# Quercus palustris                       53185
# Acer platanoides                        34189
# ...                                       ...
# Pinus nigra                                37
# Pinus rigida                               33
# Maclura pomifera                           29
# Pinus sylvestris                           25
# Pinus virginiana                           10
#
# [132 rows x 1 columns]

# %%
pd.DataFrame(tree_census_subset['spc_latin'].value_counts()).plot(kind ='bar',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
tree_census_subset['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
tree_census_subset['curb_loc'].value_counts()
# Out:
# OnCurb            656896
# OffsetFromCurb     26892
# Name: curb_loc, dtype: int64

# %%
stumps = tree_census_subset[tree_census_subset['status']=='Stump']

# %%
stumps
# Out:
#         tree_id  block_id  tree_dbh  stump_diam curb_loc status health  \
# 37       211205    302080         0          16   OnCurb  Stump    NaN
# 239      203597    301947         0          15   OnCurb  Stump    NaN
# 641      179766    230466         0          30   OnCurb  Stump    NaN
# 644      180619    348834         0          10   OnCurb  Stump    NaN
# 646      208828    107238         0          15   OnCurb  Stump    NaN
# ...         ...       ...       ...         ...      ...    ...    ...
# 683348   152836    217718         0          13   OnCurb  Stump    NaN
# 683686   191219    321689         0          25   OnCurb  Stump    NaN
# 683695   170888    231931         0           5   OnCurb  Stump    NaN
# 683697   177922    410634         0          17   OnCurb  Stump    NaN
# 683699   172660    349995         0           4   OnCurb  Stump    NaN
#
#        spc_latin steward sidewalk         user_type problems root_stone  \
# 37           NaN     NaN      NaN  TreesCount Staff      NaN         No
# 239          NaN     NaN      NaN         Volunteer      NaN         No
# 641          NaN     NaN      NaN  TreesCount Staff      NaN         No
# 644          NaN     NaN      NaN  TreesCount Staff      NaN         No
# 646          NaN     NaN      NaN         Volunteer      NaN         No
# ...          ...     ...      ...               ...      ...        ...
# 683348       NaN     NaN      NaN         Volunteer      NaN         No
# 683686       NaN     NaN      NaN   NYC Parks Staff      NaN         No
# 683695       NaN     NaN      NaN  TreesCount Staff      NaN         No
# 683697       NaN     NaN      NaN         Volunteer      NaN         No
# 683699       NaN     NaN      NaN  TreesCount Staff      NaN         No
#
#        root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# 37             No         No         No         No         No         No
# 239            No         No         No         No         No         No
# 641            No         No         No         No         No         No
# 644            No         No         No         No         No         No
# 646            No         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683348         No         No         No         No         No         No
# 683686         No         No         No         No         No         No
# 683695         No         No         No         No         No         No
# 683697         No         No         No         No         No         No
# 683699         No         No         No         No         No         No
#
#        brch_shoe brch_other
# 37            No         No
# 239           No         No
# 641           No         No
# 644           No         No
# 646           No         No
# ...          ...        ...
# 683348        No         No
# 683686        No         No
# 683695        No         No
# 683697        No         No
# 683699        No         No
#
# [17654 rows x 21 columns]

# %%
Deaths = tree_census_subset[tree_census_subset['status']=='Dead']
Deaths
# Out:
#         tree_id  block_id  tree_dbh  stump_diam        curb_loc status health  \
# 57       187807    506266         0           0          OnCurb   Dead    NaN
# 196      208322    222858        10           0          OnCurb   Dead    NaN
# 209      209058    415850         6           0          OnCurb   Dead    NaN
# 266      210544    216081         6           0          OnCurb   Dead    NaN
# 285      188609    107627         9           0          OnCurb   Dead    NaN
# ...         ...       ...       ...         ...             ...    ...    ...
# 682816   184342    505510        11           0          OnCurb   Dead    NaN
# 682823   155430    217978         2           0          OnCurb   Dead    NaN
# 683346   156566    514686        10           0          OnCurb   Dead    NaN
# 683693   156162    108193         3           0  OffsetFromCurb   Dead    NaN
# 683698   193791    208850         3           0          OnCurb   Dead    NaN
#
#        spc_latin steward sidewalk         user_type problems root_stone  \
# 57           NaN     NaN      NaN         Volunteer      NaN         No
# 196          NaN     NaN      NaN         Volunteer      NaN         No
# 209          NaN     NaN      NaN  TreesCount Staff      NaN         No
# 266          NaN     NaN      NaN         Volunteer      NaN         No
# 285          NaN     NaN      NaN         Volunteer      NaN         No
# ...          ...     ...      ...               ...      ...        ...
# 682816       NaN     NaN      NaN         Volunteer      NaN         No
# 682823       NaN     NaN      NaN         Volunteer      NaN         No
# 683346       NaN     NaN      NaN         Volunteer      NaN         No
# 683693       NaN     NaN      NaN         Volunteer      NaN         No
# 683698       NaN     NaN      NaN  TreesCount Staff      NaN         No
#
#        root_grate root_other trunk_wire trnk_light trnk_other brch_light  \
# 57             No         No         No         No         No         No
# 196            No         No         No         No         No         No
# 209            No         No         No         No         No         No
# 266            No         No         No         No         No         No
# 285            No         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 682816         No         No         No         No         No         No
# 682823         No         No         No         No         No         No
# 683346         No         No         No         No         No         No
# 683693         No         No         No         No         No         No
# 683698         No         No         No         No         No         No
#
#        brch_shoe brch_other
# 57            No         No
# 196           No         No
# 209           No         No
# 266           No         No
# 285           No         No
# ...          ...        ...
# 682816        No         No
# 682823        No         No
# 683346        No         No
# 683693        No         No
# 683698        No         No
#
# [13961 rows x 21 columns]

# %%
Deaths.value_counts()
# Out:
# Series([], dtype: int64)

# %%
tree_problems = tree_census_subset[['root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_problems
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# 1              No        No         No
# 2              No        No         No
# 3              No        No         No
# 4              No        No         No
# ...           ...       ...        ...
# 683783         No        No         No
# 683784         No        No         No
# 683785         No        No         No
# 683786         No        No         No
# 683787         No        No         No
#
# [683788 rows x 9 columns]

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %%
mask = ((tree_census_subset['status'] == 'Stump') | (tree_census_subset['status'] == 'Dead'))

# %%
tree_census_subset.loc[mask,'health'] = tree_census_subset.loc[mask,'health'].fillna('Not Applicable')
# Out:
# C:\Users\15512\Downloads\Anaconda\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
tree_census_subset[tree_census_subset['status'] == 'Stump']
# Out:
#         tree_id  block_id  tree_dbh  stump_diam curb_loc status  \
# 37       211205    302080         0          16   OnCurb  Stump
# 239      203597    301947         0          15   OnCurb  Stump
# 641      179766    230466         0          30   OnCurb  Stump
# 644      180619    348834         0          10   OnCurb  Stump
# 646      208828    107238         0          15   OnCurb  Stump
# ...         ...       ...       ...         ...      ...    ...
# 683348   152836    217718         0          13   OnCurb  Stump
# 683686   191219    321689         0          25   OnCurb  Stump
# 683695   170888    231931         0           5   OnCurb  Stump
# 683697   177922    410634         0          17   OnCurb  Stump
# 683699   172660    349995         0           4   OnCurb  Stump
#
#                 health spc_latin steward sidewalk         user_type problems  \
# 37      Not Applicable       NaN     NaN      NaN  TreesCount Staff      NaN
# 239     Not Applicable       NaN     NaN      NaN         Volunteer      NaN
# 641     Not Applicable       NaN     NaN      NaN  TreesCount Staff      NaN
# 644     Not Applicable       NaN     NaN      NaN  TreesCount Staff      NaN
# 646     Not Applicable       NaN     NaN      NaN         Volunteer      NaN
# ...                ...       ...     ...      ...               ...      ...
# 683348  Not Applicable       NaN     NaN      NaN         Volunteer      NaN
# 683686  Not Applicable       NaN     NaN      NaN   NYC Parks Staff      NaN
# 683695  Not Applicable       NaN     NaN      NaN  TreesCount Staff      NaN
# 683697  Not Applicable       NaN     NaN      NaN         Volunteer      NaN
# 683699  Not Applicable       NaN     NaN      NaN  TreesCount Staff      NaN
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 37             No         No         No         No         No         No
# 239            No         No         No         No         No         No
# 641            No         No         No         No         No         No
# 644            No         No         No         No         No         No
# 646            No         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683348         No         No         No         No         No         No
# 683686         No         No         No         No         No         No
# 683695         No         No         No         No         No         No
# 683697         No         No         No         No         No         No
# 683699         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 37             No        No         No
# 239            No        No         No
# 641            No        No         No
# 644            No        No         No
# 646            No        No         No
# ...           ...       ...        ...
# 683348         No        No         No
# 683686         No        No         No
# 683695         No        No         No
# 683697         No        No         No
# 683699         No        No         No
#
# [17654 rows x 21 columns]

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id           0
# block_id          0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health            1
# spc_latin     31619
# steward       31615
# sidewalk      31616
# user_type         0
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['sidewalk'].isna()]
# Out:
#         tree_id  block_id  tree_dbh  stump_diam        curb_loc status  \
# 37       211205    302080         0          16          OnCurb  Stump
# 57       187807    506266         0           0          OnCurb   Dead
# 196      208322    222858        10           0          OnCurb   Dead
# 209      209058    415850         6           0          OnCurb   Dead
# 239      203597    301947         0          15          OnCurb  Stump
# ...         ...       ...       ...         ...             ...    ...
# 683693   156162    108193         3           0  OffsetFromCurb   Dead
# 683695   170888    231931         0           5          OnCurb  Stump
# 683697   177922    410634         0          17          OnCurb  Stump
# 683698   193791    208850         3           0          OnCurb   Dead
# 683699   172660    349995         0           4          OnCurb  Stump
#
#                 health spc_latin steward sidewalk         user_type problems  \
# 37      Not Applicable       NaN     NaN      NaN  TreesCount Staff      NaN
# 57      Not Applicable       NaN     NaN      NaN         Volunteer      NaN
# 196     Not Applicable       NaN     NaN      NaN         Volunteer      NaN
# 209     Not Applicable       NaN     NaN      NaN  TreesCount Staff      NaN
# 239     Not Applicable       NaN     NaN      NaN         Volunteer      NaN
# ...                ...       ...     ...      ...               ...      ...
# 683693  Not Applicable       NaN     NaN      NaN         Volunteer      NaN
# 683695  Not Applicable       NaN     NaN      NaN  TreesCount Staff      NaN
# 683697  Not Applicable       NaN     NaN      NaN         Volunteer      NaN
# 683698  Not Applicable       NaN     NaN      NaN  TreesCount Staff      NaN
# 683699  Not Applicable       NaN     NaN      NaN  TreesCount Staff      NaN
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 37             No         No         No         No         No         No
# 57             No         No         No         No         No         No
# 196            No         No         No         No         No         No
# 209            No         No         No         No         No         No
# 239            No         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683693         No         No         No         No         No         No
# 683695         No         No         No         No         No         No
# 683697         No         No         No         No         No         No
# 683698         No         No         No         No         No         No
# 683699         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 37             No        No         No
# 57             No        No         No
# 196            No        No         No
# 209            No        No         No
# 239            No        No         No
# ...           ...       ...        ...
# 683693         No        No         No
# 683695         No        No         No
# 683697         No        No         No
# 683698         No        No         No
# 683699         No        No         No
#
# [31616 rows x 21 columns]

# %%
tree_census_subset['problems'].fillna('None',inplace = True)
tree_census_subset['health'].fillna('Good',inplace = True)
tree_census_subset['steward'].fillna('No Observation',inplace = True)
tree_census_subset['sidewalk'].fillna('NoDamage',inplace = True)
tree_census_subset['spc_latin'].fillna('Not recognized',inplace = True)

# %%
tree_census_subset['sidewalk'].value_counts()
# Out:
# NoDamage    496594
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
tree_census_subset['steward'].value_counts()
# Out:
# None              487823
# 1or2              143557
# No Observation     31615
# 3or4               19183
# 4orMore             1610
# Name: steward, dtype: int64

# %%
tree_census_subset['health'].value_counts()
# Out:
# Good              528851
# Fair               96504
# Not Applicable     31615
# Poor               26818
# Name: health, dtype: int64

# %%
tree_census_subset['problems'].value_counts()
# Out:
# None                                                                          457944
# Stones                                                                         95673
# BranchLights                                                                   29452
# Stones,BranchLights                                                            17808
# RootOther                                                                      11418
#                                                                                ...
# Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther         1
# MetalGrates,RootOther,WiresRope,TrunkLights,BranchLights,BranchOther               1
# MetalGrates,WiresRope,TrunkLights,BranchLights,BranchOther                         1
# Stones,MetalGrates,TrunkLights,TrunkOther                                          1
# MetalGrates,TrunkOther,Sneakers                                                    1
# Name: problems, Length: 232, dtype: int64

# %%
tree_census_subset['spc_latin'].value_counts()
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 133, dtype: int64

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id       0
# block_id      0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# steward       0
# sidewalk      0
# user_type     0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %%
big_trees = tree_census_subset[(tree_census_subset['tree_dbh']>60) | (tree_census_subset['stump_diam']>60)]

# %%
big_trees
# Out:
#         tree_id  block_id  tree_dbh  stump_diam        curb_loc status  \
# 2405     168583    226040       425           0          OnCurb  Alive
# 4887     139665    409474        72           0  OffsetFromCurb  Alive
# 6466     166008    226028         0          72          OnCurb  Stump
# 6724     209349    415127       122           0          OnCurb  Alive
# 7042     206818    311117         0         100          OnCurb  Stump
# ...         ...       ...       ...         ...             ...    ...
# 667425   151958    330826        66           0  OffsetFromCurb  Alive
# 673105   165324    206090        79           0          OnCurb  Alive
# 674016   184879    504315       105           0          OnCurb  Alive
# 681736   179366    349326       281           0          OnCurb  Alive
# 682788   183910    505123       127           0          OnCurb   Dead
#
#                 health                           spc_latin         steward  \
# 2405              Good                     Quercus bicolor            1or2
# 4887              Good                    Acer saccharinum            None
# 6466    Not Applicable                      Not recognized  No Observation
# 6724              Good                   Quercus palustris            None
# 7042    Not Applicable                      Not recognized  No Observation
# ...                ...                                 ...             ...
# 667425            Fair                       Quercus rubra            None
# 673105            Good  Gleditsia triacanthos var. inermis            None
# 674016            Fair                       Ginkgo biloba            None
# 681736            Fair                   Quercus palustris            None
# 682788  Not Applicable                      Not recognized  No Observation
#
#         sidewalk         user_type problems root_stone root_grate root_other  \
# 2405      Damage   NYC Parks Staff     None         No         No         No
# 4887    NoDamage  TreesCount Staff     None         No         No         No
# 6466    NoDamage   NYC Parks Staff     None         No         No         No
# 6724      Damage  TreesCount Staff     None         No         No         No
# 7042    NoDamage  TreesCount Staff     None         No         No         No
# ...          ...               ...      ...        ...        ...        ...
# 667425  NoDamage  TreesCount Staff     None         No         No         No
# 673105    Damage  TreesCount Staff   Stones        Yes         No         No
# 674016    Damage         Volunteer   Stones        Yes         No         No
# 681736    Damage  TreesCount Staff     None         No         No         No
# 682788  NoDamage         Volunteer     None         No         No         No
#
#        trunk_wire trnk_light trnk_other brch_light brch_shoe brch_other
# 2405           No         No         No         No        No         No
# 4887           No         No         No         No        No         No
# 6466           No         No         No         No        No         No
# 6724           No         No         No         No        No         No
# 7042           No         No         No         No        No         No
# ...           ...        ...        ...        ...       ...        ...
# 667425         No         No         No         No        No         No
# 673105         No         No         No         No        No         No
# 674016         No         No         No         No        No         No
# 681736         No         No         No         No        No         No
# 682788         No         No         No         No        No         No
#
# [245 rows x 21 columns]

# %%
big_trees['tree_dbh'].value_counts()
# Out:
# 0      92
# 64     17
# 62      5
# 71      5
# 63      5
#        ..
# 98      1
# 147     1
# 154     1
# 250     1
# 281     1
# Name: tree_dbh, Length: 86, dtype: int64

# %%
big_trees['stump_diam'].value_counts()
# Out:
# 0      153
# 65       8
# 61       5
# 63       5
# 70       5
# 85       4
# 77       4
# 78       4
# 67       4
# 80       4
# 62       4
# 76       3
# 66       3
# 64       3
# 79       3
# 87       2
# 89       2
# 71       2
# 100      2
# 69       2
# 74       2
# 90       2
# 84       2
# 98       1
# 107      1
# 86       1
# 82       1
# 104      1
# 125      1
# 131      1
# 115      1
# 99       1
# 92       1
# 72       1
# 96       1
# 134      1
# 109      1
# 118      1
# 140      1
# 120      1
# Name: stump_diam, dtype: int64

# %%
tree_census_subset = tree_census_subset[(tree_census_subset['tree_dbh']<=60) | (tree_census_subset['stump_diam']<=60)]
tree_census_subset
# Out:
#         tree_id  block_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683    348711         3           0   OnCurb  Alive   Fair
# 1        200540    315986        21           0   OnCurb  Alive   Fair
# 2        204026    218365         3           0   OnCurb  Alive   Good
# 3        204337    217969        10           0   OnCurb  Alive   Good
# 4        189565    223043        21           0   OnCurb  Alive   Good
# ...         ...       ...       ...         ...      ...    ...    ...
# 683783   155433    217978        25           0   OnCurb  Alive   Good
# 683784   183795    348185         7           0   OnCurb  Alive   Good
# 683785   166161    401670        12           0   OnCurb  Alive   Good
# 683786   184028    504204         9           0   OnCurb  Alive   Good
# 683787   200607    306527        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk  \
# 0                              Acer rubrum    None  NoDamage
# 1                        Quercus palustris    None    Damage
# 2       Gleditsia triacanthos var. inermis    1or2    Damage
# 3       Gleditsia triacanthos var. inermis    None    Damage
# 4                          Tilia americana    None    Damage
# ...                                    ...     ...       ...
# 683783                   Quercus palustris    None    Damage
# 683784                 Cladrastis kentukea    1or2  NoDamage
# 683785                         Acer rubrum    None    Damage
# 683786                         Acer rubrum    None  NoDamage
# 683787                         Acer rubrum    None  NoDamage
#
#                user_type problems root_stone root_grate root_other trunk_wire  \
# 0       TreesCount Staff     None         No         No         No         No
# 1       TreesCount Staff   Stones        Yes         No         No         No
# 2              Volunteer     None         No         No         No         No
# 3              Volunteer   Stones        Yes         No         No         No
# 4              Volunteer   Stones        Yes         No         No         No
# ...                  ...      ...        ...        ...        ...        ...
# 683783         Volunteer     None         No         No         No         No
# 683784         Volunteer     None         No         No         No         No
# 683785         Volunteer     None         No         No         No         No
# 683786  TreesCount Staff     None         No         No         No         No
# 683787  TreesCount Staff     None         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 0              No         No         No        No         No
# 1              No         No         No        No         No
# 2              No         No         No        No         No
# 3              No         No         No        No         No
# 4              No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 683783         No         No         No        No         No
# 683784         No         No         No        No         No
# 683785         No         No         No        No         No
# 683786         No         No         No        No         No
# 683787         No         No         No        No         No
#
# [683788 rows x 21 columns]

# %%
tree_census_subset.value_counts()
# Out:
# tree_id  block_id  tree_dbh  stump_diam  curb_loc  status  health  spc_latin                           steward  sidewalk  user_type         problems   root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  brch_light  brch_shoe  brch_other
# 3        501451    24        0           OnCurb    Alive   Good    Quercus palustris                   1or2     Damage    NYC Parks Staff   None       No          No          No          No          No          No          No          No         No            1
# 485219   225662    3         0           OnCurb    Alive   Good    Ginkgo biloba                       1or2     NoDamage  TreesCount Staff  None       No          No          No          No          No          No          No          No         No            1
# 485221   225662    3         0           OnCurb    Alive   Good    Ginkgo biloba                       1or2     NoDamage  TreesCount Staff  None       No          No          No          No          No          No          No          No         No            1
# 485222   225662    3         0           OnCurb    Alive   Good    Ginkgo biloba                       1or2     Damage    TreesCount Staff  None       No          No          No          No          No          No          No          No         No            1
# 485223   225662    20        0           OnCurb    Alive   Good    Platanus x acerifolia               None     NoDamage  TreesCount Staff  WiresRope  No          No          No          Yes         No          No          No          No         No            1
#                                                                                                                                                                                                                                                                    ..
# 246534   335034    10        0           OnCurb    Alive   Good    Gleditsia triacanthos var. inermis  None     NoDamage  TreesCount Staff  None       No          No          No          No          No          No          No          No         No            1
# 246535   335034    10        0           OnCurb    Alive   Good    Gleditsia triacanthos var. inermis  None     NoDamage  TreesCount Staff  None       No          No          No          No          No          No          No          No         No            1
# 246536   335034    12        0           OnCurb    Alive   Good    Gleditsia triacanthos var. inermis  None     Damage    TreesCount Staff  None       No          No          No          No          No          No          No          No         No            1
# 246537   414410    27        0           OnCurb    Alive   Fair    Platanus x acerifolia               None     NoDamage  TreesCount Staff  None       No          No          No          No          No          No          No          No         No            1
# 722694   999999    3         0           OnCurb    Alive   Good    Tilia cordata                       None     NoDamage  NYC Parks Staff   None       No          No          No          No          No          No          No          No         No            1
# Length: 683788, dtype: int64

# %%
tree_census_subset_alive = tree_census_subset[tree_census_subset['status']== 'Alive']
tree_census_subset_dead_or_stump = tree_census_subset[(tree_census_subset['status'] == 'Dead') | (tree_census_subset['status']=='Stump')]

# %%
tree_census_subset_alive
# Out:
#         tree_id  block_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683    348711         3           0   OnCurb  Alive   Fair
# 1        200540    315986        21           0   OnCurb  Alive   Fair
# 2        204026    218365         3           0   OnCurb  Alive   Good
# 3        204337    217969        10           0   OnCurb  Alive   Good
# 4        189565    223043        21           0   OnCurb  Alive   Good
# ...         ...       ...       ...         ...      ...    ...    ...
# 683783   155433    217978        25           0   OnCurb  Alive   Good
# 683784   183795    348185         7           0   OnCurb  Alive   Good
# 683785   166161    401670        12           0   OnCurb  Alive   Good
# 683786   184028    504204         9           0   OnCurb  Alive   Good
# 683787   200607    306527        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk  \
# 0                              Acer rubrum    None  NoDamage
# 1                        Quercus palustris    None    Damage
# 2       Gleditsia triacanthos var. inermis    1or2    Damage
# 3       Gleditsia triacanthos var. inermis    None    Damage
# 4                          Tilia americana    None    Damage
# ...                                    ...     ...       ...
# 683783                   Quercus palustris    None    Damage
# 683784                 Cladrastis kentukea    1or2  NoDamage
# 683785                         Acer rubrum    None    Damage
# 683786                         Acer rubrum    None  NoDamage
# 683787                         Acer rubrum    None  NoDamage
#
#                user_type problems root_stone root_grate root_other trunk_wire  \
# 0       TreesCount Staff     None         No         No         No         No
# 1       TreesCount Staff   Stones        Yes         No         No         No
# 2              Volunteer     None         No         No         No         No
# 3              Volunteer   Stones        Yes         No         No         No
# 4              Volunteer   Stones        Yes         No         No         No
# ...                  ...      ...        ...        ...        ...        ...
# 683783         Volunteer     None         No         No         No         No
# 683784         Volunteer     None         No         No         No         No
# 683785         Volunteer     None         No         No         No         No
# 683786  TreesCount Staff     None         No         No         No         No
# 683787  TreesCount Staff     None         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 0              No         No         No        No         No
# 1              No         No         No        No         No
# 2              No         No         No        No         No
# 3              No         No         No        No         No
# 4              No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 683783         No         No         No        No         No
# 683784         No         No         No        No         No
# 683785         No         No         No        No         No
# 683786         No         No         No        No         No
# 683787         No         No         No        No         No
#
# [652173 rows x 21 columns]

# %%
tree_census_subset_dead_or_stump
# Out:
#         tree_id  block_id  tree_dbh  stump_diam        curb_loc status  \
# 37       211205    302080         0          16          OnCurb  Stump
# 57       187807    506266         0           0          OnCurb   Dead
# 196      208322    222858        10           0          OnCurb   Dead
# 209      209058    415850         6           0          OnCurb   Dead
# 239      203597    301947         0          15          OnCurb  Stump
# ...         ...       ...       ...         ...             ...    ...
# 683693   156162    108193         3           0  OffsetFromCurb   Dead
# 683695   170888    231931         0           5          OnCurb  Stump
# 683697   177922    410634         0          17          OnCurb  Stump
# 683698   193791    208850         3           0          OnCurb   Dead
# 683699   172660    349995         0           4          OnCurb  Stump
#
#                 health       spc_latin         steward  sidewalk  \
# 37      Not Applicable  Not recognized  No Observation  NoDamage
# 57      Not Applicable  Not recognized  No Observation  NoDamage
# 196     Not Applicable  Not recognized  No Observation  NoDamage
# 209     Not Applicable  Not recognized  No Observation  NoDamage
# 239     Not Applicable  Not recognized  No Observation  NoDamage
# ...                ...             ...             ...       ...
# 683693  Not Applicable  Not recognized  No Observation  NoDamage
# 683695  Not Applicable  Not recognized  No Observation  NoDamage
# 683697  Not Applicable  Not recognized  No Observation  NoDamage
# 683698  Not Applicable  Not recognized  No Observation  NoDamage
# 683699  Not Applicable  Not recognized  No Observation  NoDamage
#
#                user_type problems root_stone root_grate root_other trunk_wire  \
# 37      TreesCount Staff     None         No         No         No         No
# 57             Volunteer     None         No         No         No         No
# 196            Volunteer     None         No         No         No         No
# 209     TreesCount Staff     None         No         No         No         No
# 239            Volunteer     None         No         No         No         No
# ...                  ...      ...        ...        ...        ...        ...
# 683693         Volunteer     None         No         No         No         No
# 683695  TreesCount Staff     None         No         No         No         No
# 683697         Volunteer     None         No         No         No         No
# 683698  TreesCount Staff     None         No         No         No         No
# 683699  TreesCount Staff     None         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 37             No         No         No        No         No
# 57             No         No         No        No         No
# 196            No         No         No        No         No
# 209            No         No         No        No         No
# 239            No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 683693         No         No         No        No         No
# 683695         No         No         No        No         No
# 683697         No         No         No        No         No
# 683698         No         No         No        No         No
# 683699         No         No         No        No         No
#
# [31615 rows x 21 columns]

# %%
tree_census_subset_alive.groupby('spc_latin').mean()
# Out:
#                          tree_id       block_id   tree_dbh  stump_diam
# spc_latin
# Acer               473760.032486  381788.887853  11.675424         0.0
# Acer buergerianum  395036.818182  342933.872727   8.090909         0.0
# Acer campestre     383840.281176  371784.357255   7.126275         0.0
# Acer ginnala       370801.015129  373497.061493   7.869204         0.0
# Acer griseum       347632.222727  330247.772727   3.509091         0.0
# ...                          ...            ...        ...         ...
# Tsuga canadensis   268551.181818  304715.250000   5.193182         0.0
# Ulmus americana    308680.330533  299263.998370  11.953229         0.0
# Ulmus parvifolia   303458.441347  317659.403181   7.417587         0.0
# Ulmus pumila       318869.944828  326428.443260  11.475862         0.0
# Zelkova serrata    345718.008989  298801.241062   7.863559         0.0
#
# [133 rows x 4 columns]

# %%
tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe()
# Out:
#                      count       mean       std  min  25%   50%   75%    max
# spc_latin
# Acer                7080.0  11.675424  6.577626  0.0  7.0  11.0  15.0   59.0
# Acer buergerianum    110.0   8.090909  4.544470  2.0  5.0   8.0  10.0   28.0
# Acer campestre      2550.0   7.126275  4.437674  0.0  4.0   6.0   9.0   64.0
# Acer ginnala        2049.0   7.869204  4.853365  0.0  4.0   7.0  10.0   40.0
# Acer griseum         220.0   3.509091  3.578846  1.0  2.0   2.0   3.0   30.0
# ...                    ...        ...       ...  ...  ...   ...   ...    ...
# Tsuga canadensis      88.0   5.193182  3.959153  0.0  2.0   3.5   7.0   21.0
# Ulmus americana     7975.0  11.953229  9.426278  0.0  4.0   9.0  17.0   65.0
# Ulmus parvifolia    5345.0   7.417587  5.867390  0.0  3.0   5.0  10.0  118.0
# Ulmus pumila        1595.0  11.475862  9.903164  1.0  4.0   9.0  17.0  149.0
# Zelkova serrata    29258.0   7.863559  5.297524  0.0  4.0   6.0  11.0  210.0
#
# [133 rows x 8 columns]

# %%
stats_alive = tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe().reset_index()[['spc_latin','25%','75%']]
stats_alive
# Out:
#              spc_latin  25%   75%
# 0                 Acer  7.0  15.0
# 1    Acer buergerianum  5.0  10.0
# 2       Acer campestre  4.0   9.0
# 3         Acer ginnala  4.0  10.0
# 4         Acer griseum  2.0   3.0
# ..                 ...  ...   ...
# 128   Tsuga canadensis  2.0   7.0
# 129    Ulmus americana  4.0  17.0
# 130   Ulmus parvifolia  3.0  10.0
# 131       Ulmus pumila  4.0  17.0
# 132    Zelkova serrata  4.0  11.0
#
# [133 rows x 3 columns]
